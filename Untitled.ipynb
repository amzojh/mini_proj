# %%
import pandas as pd
import numpy as np

df = pd.read_excel("company_info_2.xlsx")

# %%
num = df.values

# %%
a = num.flatten()

# %%
b = list(a)

# %%
b.pop(0)
# Out:
# 0

# %%
pd.DataFrame(b)
# Out:
#                                                        0
# 0      {'company_korean_name': '가가담목재(주)', 'company_e...
# 1      {'company_korean_name': '(주)가겐투안', 'company_en...
# 2      {'company_korean_name': '주식회사 가경', 'company_en...
# 3      {'company_korean_name': '주식회사 가경', 'company_en...
# 4      {'company_korean_name': '(주)가경개발', 'company_en...
# ...                                                  ...
# 15588                                                NaN
# 15589                                                NaN
# 15590                                                NaN
# 15591                                                NaN
# 15592                                                NaN
#
# [15593 rows x 1 columns]

# %%
df
# Out:
#      Unnamed: 0                                                  0  \
# 0             0  {'company_korean_name': '가가담목재(주)', 'company_e...
# 1             1  {'company_korean_name': '주식회사 가디언홀딩스', 'compan...
# 2             2  {'company_korean_name': '주식회사 가산일렉트론', 'compan...
# 3             3  {'company_korean_name': '가온소프트(주)', 'company_e...
# 4             4  {'company_korean_name': '가이아디벡스제오차주식회사', 'comp...
# ..          ...                                                ...
# 334         334  {'company_korean_name': '디지틀스포츠투데이(주)', 'compa...
# 335         335  {'company_korean_name': '주식회사 디케이비즈니스', 'compa...
# 336         336  {'company_korean_name': '디케이제일차 주식회사', 'compan...
# 337         337  {'company_korean_name': '디트루', 'company_englis...
# 338         338  {'company_korean_name': '주식회사 디피코 홀딩스', 'compa...
#
#                                                      1  \
# 0    {'company_korean_name': '(주)가겐투안', 'company_en...
# ...

# %%
df.loc[:, ['C', 'D']]
# Out:
#           C         D
# 0 -0.504117  0.304612
# 1       NaN       NaN
# 2  1.442619 -0.406049

# %%
df.loc[:, ['C', 'D']].fillna(-1, inplace=True)

# %%
df.loc[:, ['C', 'D']]
# Out:
#           C         D
# 0 -0.504117  0.304612
# 1  0.000000  0.000000
# 2  1.442619 -0.406049

# %%
df.fillna(0, inplace=True)

# %%
df
# Out:
#           A         B         C         D
# 0  0.861490  0.140177 -0.504117  0.304612
# 1  0.976462 -2.716837  0.000000  0.000000
# 2 -0.666406 -0.132507  1.442619 -0.406049

# %%
for i in range(1):
    print(1)
# Out:
# 1
